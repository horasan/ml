# %% [markdown]
# <a href="https://colab.research.google.com/github/horasan/ml/blob/main/00_CEB_TEMP_NOTES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive
# %matplotlib inline
import plotly.graph_objects as go
import plotly.express as px
import scipy.stats as stats
from IPython.display import display, HTML
import math
sns.set_style('darkgrid')
pd.set_option('display.max_columns', None) # all the columns will be shown
pd.set_option('display.max_rows', 99) # 99 of the possible rows will be shown
import calendar
import datetime
from dateutil.relativedelta import relativedelta

# %%
#drive.mount('/content/drive')
#DRIVE_DATASET_PATH = "/content/drive/My Drive/Colab Notebooks/0_R_LER/TREASURY/"

# %% [markdown]
# # 0) Functions

# %% [markdown]
# ## 1

# %%
# TODO: Document needed,
# TODO: There is no exception handling
def calculate_compounded_interest(X, m, r, t):
  P_t = ((1 + r / m)**(t*m))*X
  return P_t

# %% [markdown]
# # NOTES

# %% [markdown]
# # OTHER

# %%
# initialize bond information.
bond_info = {
    'coupon_value': [1.0, 2.0, 3.0, 4.0],
    'time': [1.0, 2.0, 3.0, 4.0]
    }

# Create DataFrame
bond_data = pd.DataFrame(bond_info)

# add 'present value' data to dataframe
bond_data["some_value"] = bond_data.apply(lambda row: row["coupon_value"] * 1.5, axis=1)

bond_data
# Out:
#    coupon_value  time  some_value
# 0           1.0   1.0         1.5
# 1           2.0   2.0         3.0
# 2           3.0   3.0         4.5
# 3           4.0   4.0         6.0

# %%
interest_rate = 3.5
payment_frequency = 2 # semi-annually

coupon_amount = 500000 * interest_rate / 100 / payment_frequency
print("coupon_amount:", coupon_amount)

currentCalculation = coupon_amount * 17 / 30
print("currentCalculation:", currentCalculation)

short_coupon_calculation = coupon_amount * 30 / 184 * 17 / 30
print("short_coupon_calculation:", short_coupon_calculation)

FHM87145_net_return_rate = interest_rate / 100 / payment_frequency * 30 / 184
print("net_return:", FHM87145_net_return_rate)
# Out:
# coupon_amount: 8750.0
# currentCalculation: 4958.333333333333
# short_coupon_calculation: 808.4239130434783
# net_return: 0.0028532608695652174
