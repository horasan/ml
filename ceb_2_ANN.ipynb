# %% [markdown]
# <a href="https://colab.research.google.com/github/horasan/ml/blob/main/ceb_2_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.youtube.com/watch?v=Wqmtf9SA_kk
#https://www.kaggle.com/datasets/camnugent/california-housing-prices
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

# %%
# read data from google drive
drive.mount('/content/drive')
DRIVE_DATASET_PATH = "/content/drive/My Drive/Colab Notebooks/datasets/"
# Out:
# Mounted at /content/drive

# %%
#housing.csv
data = pd.read_csv(DRIVE_DATASET_PATH +"housing.csv")
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# * we can see the data description here
# https://www.youtube.com/watch?v=Wqmtf9SA_kk
#
# !!! Burai yanlis. kaggle link' i olmasi laizm"""
#
# * label (target value, true value) is median_house_value

# %%
# ocean_proximity is text we cannot use directly. We need to preprocess(feature engineering) this values.

# %%
# lets see the simple data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# 4   total_bedrooms      20433 non-null  float64
# total_bedrooms has some missing data. We can process but here for simplicity,
# I will just drop the rows with null values (since # is small)
data.dropna(inplace = True)

# %%
# rows with null values are dropped.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# lets do some analysis on the data.

# %%
# histogram gives a powerful visualization
data.hist(figsize=(15,8))
# households, median_income and households are left sided, not bell curved!
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# correlation and heatmap are other powerfull visualization tools (corr, heatmap are missing)

# %%
#data.corr()

# %%
# households, total_rooms, total_bedrooms and population are left sided, not bell curved!
# so log might help on this one.

# %%
data["total_rooms"] = np.log(data["total_rooms"] + 1) # +1 for 0 values
data["total_bedrooms"] = np.log(data["total_bedrooms"] + 1) # +1 for 0 values
data["population"] = np.log(data["population"] + 1) # +1 for 0 values
data["households"] = np.log(data["households"] + 1) # +1 for 0 values

# %%
# once again we will use histogram
data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# # about ocean_proximity
#
# 1) This columns does not have number values so we need to provide some kind of numbers which represent the ocean_proximity values.
#
# 2) But we cannot replace the categories with a number.
# Lets say, we cannot replace like
# *   NEAR OCEAN --> 1
# *   INLAND --> 2
#
# 3) We will use the technique called one-hot encoding!
#
# NOTE: sklearn has also one-hot encoding feature but i will use panda version.

# %%
# about ocean_proximity
data["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %%
# each value is converted to a column for each row
# then these new columns can be used in our model (after joining to the "data").
pd.get_dummies(data["ocean_proximity"])
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0          False   False   False      True       False
# 1          False   False   False      True       False
# 2          False   False   False      True       False
# 3          False   False   False      True       False
# 4          False   False   False      True       False
# ...          ...     ...     ...       ...         ...
# 20635      False    True   False     False       False
# 20636      False    True   False     False       False
# 20637      False    True   False     False       False
# 20638      False    True   False     False       False
# 20639      False    True   False     False       False
#
# [20433 rows x 5 columns]

# %%
data = data.join(pd.get_dummies(data["ocean_proximity"]))

# %%
# then now we can drop the "ocean_proximity" column
data.drop(["ocean_proximity"], axis = 1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0     6.781058        4.867534
# 1        -122.22     37.86                21.0     8.867850        7.009409
# 2        -122.24     37.85                52.0     7.291656        5.252273
# 3        -122.25     37.85                52.0     7.150701        5.463832
# 4        -122.25     37.85                52.0     7.395108        5.638355
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0     7.418181        5.926926
# 20636    -121.21     39.49                18.0     6.548219        5.017280
# 20637    -121.22     39.43                17.0     7.720905        6.186209
# 20638    -121.32     39.43                18.0     7.528869        6.016157
# 20639    -121.24     39.37                16.0     7.932362        6.424869
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 0        5.777652    4.844187         8.3252            452600.0      False
# 1        7.784057    7.037906         8.3014            358500.0      False
# 2        6.208590    5.181784         7.2574            352100.0      False
# 3        6.326149    5.393628         5.6431            341300.0      False
# 4        6.338594    5.560682         3.8462            342200.0      False
# ...           ...         ...            ...                 ...        ...
# 20635    6.740519    5.802118         1.5603             78100.0      False
# 20636    5.877736    4.744932         2.5568             77100.0      False
# 20637    6.915723    6.073045         1.7000             92300.0      False
# 20638    6.609349    5.857933         1.8672             84700.0      False
# 20639    7.235619    6.274762         2.3886             89400.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0       False   False      True       False
# 1       False   False      True       False
# 2       False   False      True       False
# 3       False   False      True       False
# 4       False   False      True       False
# ...       ...     ...       ...         ...
# 20635    True   False     False       False
# 20636    True   False     False       False
# 20637    True   False     False       False
# 20638    True   False     False       False
# 20639    True   False     False       False
#
# [20433 rows x 14 columns]

# %%
data = data.drop(["ocean_proximity"], axis = 1)
# if we run the same code again we get the "['ocean_proximity'] not found in axis" error

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0     6.781058        4.867534
# 1        -122.22     37.86                21.0     8.867850        7.009409
# 2        -122.24     37.85                52.0     7.291656        5.252273
# 3        -122.25     37.85                52.0     7.150701        5.463832
# 4        -122.25     37.85                52.0     7.395108        5.638355
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0     7.418181        5.926926
# 20636    -121.21     39.49                18.0     6.548219        5.017280
# 20637    -121.22     39.43                17.0     7.720905        6.186209
# 20638    -121.32     39.43                18.0     7.528869        6.016157
# 20639    -121.24     39.37                16.0     7.932362        6.424869
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 0        5.777652    4.844187         8.3252            452600.0      False
# 1        7.784057    7.037906         8.3014            358500.0      False
# 2        6.208590    5.181784         7.2574            352100.0      False
# 3        6.326149    5.393628         5.6431            341300.0      False
# 4        6.338594    5.560682         3.8462            342200.0      False
# ...           ...         ...            ...                 ...        ...
# 20635    6.740519    5.802118         1.5603             78100.0      False
# 20636    5.877736    4.744932         2.5568             77100.0      False
# 20637    6.915723    6.073045         1.7000             92300.0      False
# 20638    6.609349    5.857933         1.8672             84700.0      False
# 20639    7.235619    6.274762         2.3886             89400.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0       False   False      True       False
# 1       False   False      True       False
# 2       False   False      True       False
# 3       False   False      True       False
# 4       False   False      True       False
# ...       ...     ...       ...         ...
# 20635    True   False     False       False
# 20636    True   False     False       False
# 20637    True   False     False       False
# 20638    True   False     False       False
# 20639    True   False     False       False
#
# [20433 rows x 14 columns]

# %% [markdown]
# # lets see the correlation about the values
# Burada bu heatmap' de neler anlatildigina, bunun nasil okunacagini biraz anlatmak gerekiyor.

# %%
# lets see the correlation about the values
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# # some feature engineering

# %% [markdown]
# see the coordinates.
#  https://www.mapsofworld.com/usa/states/california/lat-long.html

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="longitude", y ="latitude", data= data, hue="median_house_value", palette="coolwarm")
# price: closer the coast, higher the price
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# we can combine/generate more data!
#
# bedroom_ratio
#
# household_rooms

# %%
data["bedroom_ratio"] = data["total_bedrooms"] / data["total_rooms"]

# %%
data["household_rooms"] = data["total_rooms"] / data["households"]

# %%
# lets check if the new data(columns) makes sense using heatmap
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# # Developing ML models
#
# 1) First thing to do is preparing train and test data.
# !! Burada daha fazla aciklama yapmak lazim. Train data, test data nedir????
#
# 2) Artificial Neural Network

# %%
# 1) Prepare model training data and testing data
from sklearn.model_selection import train_test_split

# X has the features (but not the target label)
X = data.drop(["median_house_value"], axis=1)

# %%
y = data["median_house_value"]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=66)

# %% [markdown]
# # Before model definition and training, lets do some more data Visualization

# %%
# general stats  about the data
data.describe().transpose()
# Out:
#                       count           mean            std           min  \
# longitude           20433.0    -119.570689       2.003578   -124.350000
# latitude            20433.0      35.633221       2.136348     32.540000
# housing_median_age  20433.0      28.633094      12.591805      1.000000
# total_rooms         20433.0       7.629543       0.750260      1.098612
# total_bedrooms      20433.0       6.054708       0.726728      0.693147
# population          20433.0       7.025121       0.736336      1.386294
# households          20433.0       5.984538       0.726856      0.693147
# median_income       20433.0       3.871162       1.899291      0.499900
# median_house_value  20433.0  206864.413155  115435.667099  14999.000000
# bedroom_ratio       20433.0       0.792096       0.036717      0.315465
# household_rooms     20433.0       1.281093       0.078811      0.941589
#
#                               25%            50%            75%            max
# longitude             -121.800000    -118.490000    -118.010000    -114.310000
# latitude                33.930000      34.260000      37.720000      41.950000
# housing_median_age      18.000000      29.000000      37.000000      52.000000
# total_rooms              7.280008       7.662938       8.053251      10.579514
# total_bedrooms           5.693732       6.077642       6.473891       8.771215
# population               6.669498       7.062192       7.451822      10.482430
# households               5.638355       6.016157       6.405228       8.713253
# median_income            2.563700       3.536500       4.744000      15.000100
# median_house_value  119500.000000  179700.000000  264700.000000  500001.000000
# bedroom_ratio            0.771585       0.792726       0.813899       1.000000
# household_rooms          1.241671       1.274007       1.307734       3.560877

# %%
# distributions of the features
data.hist(bins=20, figsize=(20, 20), color = "r")
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>],
#        [<Axes: title={'center': 'bedroom_ratio'}>,
#         <Axes: title={'center': 'household_rooms'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# # 2) Artificial Neural Network
#
# We will use Dense ANN. All the nodes will be connected to each other.

# %% [markdown]
# # 2.1) With ANN, normalization of the columns values (aka scaling) is important.
#
# So as the first step, I will scale the values using MinMaxScaler.
#
# "This estimator scales and translates each feature individually such that it is in the given range on the training set, e.g. between zero and one."
#
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)

# %% [markdown]
# MinMaxScaler doesn’t reduce the effect of outliers, but it linearly scales them down into a fixed range, where the largest occurring data point corresponds to the maximum value and the smallest one corresponds to the minimum value.

# %%
temp_X_train_scaled_df = pd.DataFrame(
      X_train_scaled,
      columns=data.drop(["median_house_value"], axis=1).columns
      )

temp_X_train_scaled_df.hist(bins=20, figsize=(20, 20), color = "r")

# the distribution is the same as data.hist!!
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>,
#         <Axes: title={'center': 'total_rooms'}>],
#        [<Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>],
#        [<Axes: title={'center': '<1H OCEAN'}>,
#         <Axes: title={'center': 'INLAND'}>,
#         <Axes: title={'center': 'ISLAND'}>,
#         <Axes: title={'center': 'NEAR BAY'}>],
#        [<Axes: title={'center': 'NEAR OCEAN'}>,
#         <Axes: title={'center': 'bedroom_ratio'}>,
#         <Axes: title={'center': 'household_rooms'}>, <Axes: >]],
#       dtype=object)

# %%
X_train_scaled
# as u can see the values are scaled between 0 and 1 (min value is scaled to 0, max value is scaled to 1)
# Out:
# array([[0.2310757 , 0.50265675, 0.60784314, ..., 0.        , 0.66742579,
#         0.16368792],
#        [0.70717131, 0.02125399, 0.68627451, ..., 1.        , 0.76578036,
#         0.11970566],
#        [0.45219124, 0.44845909, 1.        , ..., 0.        , 0.68309592,
#         0.14916292],
#        ...,
#        [0.22111554, 0.51753454, 0.68627451, ..., 0.        , 0.7120392 ,
#         0.13731   ],
#        [0.60258964, 0.1477152 , 0.66666667, ..., 0.        , 0.73656037,
#         0.13324524],
#        [0.58665339, 0.15834219, 0.50980392, ..., 0.        , 0.78139262,
#         0.10988989]])

# %%
y_train = y_train.values.reshape(-1, 1)

# %%
y_train_scaled = scaler.fit_transform(y_train)

# %%
y_train_scaled
# Out:
# array([[1.        ],
#        [0.56329871],
#        [0.08680583],
#        ...,
#        [0.87814277],
#        [0.17360959],
#        [0.64391693]])

# %% [markdown]
# # 2.1) Model building and training

# %% [markdown]
# # TODO: test datalarini scale etmedim henuz!!!

# %%
# Related imports for the ANN

import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense

print(f"# of features (inputs) are {X_train.columns.size}")
# Out:
# # of features (inputs) are 15

# %%
model = Sequential()

model.add(Dense(50, input_dim=15, activation="relu")) # first layer has 50 neurons
model.add(Dense(50, activation="relu")) # second layer
model.add(Dense(1, activation="linear")) # last layer, unit is 1 because we will receive (predict) 1 value

model.summary()

print(f"\n\n What is --> dense (Dense)             (None, 50)                800")
print(f"We have 15 inputs feeding 50 neurons & 1 bias for each neuron: 15*50={15*50} + 1*50 = {15*50 + 50}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                800
#
#  dense_1 (Dense)             (None, 50)                2550
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 3401 (13.29 KB)
# Trainable params: 3401 (13.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
#  What is --> dense (Dense)             (None, 50)                800
# We have 15 inputs feeding 50 neurons & 1 bias for each neuron: 15*50=750 + 1*50 = 800

# %%
model.compile(optimizer="Adam", loss="mean_squared_error")

# %%
epochs_hist = model.fit(X_train_scaled, y_train_scaled, epochs=100, batch_size=50, validation_split=0.2)
# Out:
# Epoch 1/100
# 262/262 [==============================] - 2s 4ms/step - loss: 0.0298 - val_loss: 0.0237
# Epoch 2/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0207 - val_loss: 0.0214
# Epoch 3/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0188 - val_loss: 0.0187
# Epoch 4/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0176 - val_loss: 0.0178
# Epoch 5/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0167 - val_loss: 0.0177
# Epoch 6/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0164 - val_loss: 0.0170
# Epoch 7/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0160 - val_loss: 0.0173
# Epoch 8/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0157 - val_loss: 0.0164
# Epoch 9/100
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0155 - val_loss: 0.0162
# Epoch 10/100
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0154 - val_loss: 0.0160
# Epoch 11/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0152 - val_loss: 0.0163
# Epoch 12/100
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0150 - val_loss: 0.0158
# Epoch 13/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0149 - val_loss: 0.0156
# Epoch 14/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0150 - val_loss: 0.0159
# Epoch 15/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0146 - val_loss: 0.0158
# Epoch 16/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0145 - val_loss: 0.0155
# Epoch 17/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0144 - val_loss: 0.0189
# Epoch 18/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0145 - val_loss: 0.0153
# Epoch 19/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0145 - val_loss: 0.0172
# Epoch 20/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0142 - val_loss: 0.0163
# Epoch 21/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0143 - val_loss: 0.0150
# Epoch 22/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0141 - val_loss: 0.0154
# Epoch 23/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0138 - val_loss: 0.0152
# Epoch 24/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0141 - val_loss: 0.0158
# Epoch 25/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0137 - val_loss: 0.0148
# Epoch 26/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0138 - val_loss: 0.0148
# Epoch 27/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0141 - val_loss: 0.0150
# Epoch 28/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0137 - val_loss: 0.0146
# Epoch 29/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0136 - val_loss: 0.0149
# Epoch 30/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0138 - val_loss: 0.0149
# Epoch 31/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0138 - val_loss: 0.0149
# Epoch 32/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0134 - val_loss: 0.0148
# Epoch 33/100
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0136 - val_loss: 0.0156
# Epoch 34/100
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0134 - val_loss: 0.0146
# Epoch 35/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0133 - val_loss: 0.0146
# Epoch 36/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0133 - val_loss: 0.0145
# Epoch 37/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0134 - val_loss: 0.0144
# Epoch 38/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0133 - val_loss: 0.0149
# Epoch 39/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0135 - val_loss: 0.0154
# Epoch 40/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0131 - val_loss: 0.0156
# Epoch 41/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0130 - val_loss: 0.0147
# Epoch 42/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0130 - val_loss: 0.0146
# Epoch 43/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0129 - val_loss: 0.0143
# Epoch 44/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0133 - val_loss: 0.0146
# Epoch 45/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0130 - val_loss: 0.0154
# Epoch 46/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0129 - val_loss: 0.0144
# Epoch 47/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0129 - val_loss: 0.0148
# Epoch 48/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0127 - val_loss: 0.0147
# Epoch 49/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0128 - val_loss: 0.0162
# Epoch 50/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0127 - val_loss: 0.0139
# Epoch 51/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0126 - val_loss: 0.0147
# Epoch 52/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0128 - val_loss: 0.0155
# Epoch 53/100
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0127 - val_loss: 0.0139
# Epoch 54/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0124 - val_loss: 0.0142
# Epoch 55/100
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0126 - val_loss: 0.0140
# Epoch 56/100
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0126 - val_loss: 0.0155
# Epoch 57/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0128 - val_loss: 0.0146
# Epoch 58/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0122 - val_loss: 0.0141
# Epoch 59/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0123 - val_loss: 0.0138
# Epoch 60/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0125 - val_loss: 0.0139
# Epoch 61/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0123 - val_loss: 0.0143
# Epoch 62/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0121 - val_loss: 0.0151
# Epoch 63/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0121 - val_loss: 0.0140
# Epoch 64/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0122 - val_loss: 0.0139
# Epoch 65/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0121 - val_loss: 0.0139
# Epoch 66/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0121 - val_loss: 0.0142
# Epoch 67/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0122 - val_loss: 0.0139
# Epoch 68/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0121 - val_loss: 0.0151
# Epoch 69/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0119 - val_loss: 0.0136
# Epoch 70/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0120 - val_loss: 0.0142
# Epoch 71/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0120 - val_loss: 0.0145
# Epoch 72/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0119 - val_loss: 0.0138
# Epoch 73/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0121 - val_loss: 0.0137
# Epoch 74/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0120 - val_loss: 0.0147
# Epoch 75/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0121 - val_loss: 0.0139
# Epoch 76/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0148
# Epoch 77/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0136
# Epoch 78/100
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0122 - val_loss: 0.0134
# Epoch 79/100
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0117 - val_loss: 0.0135
# Epoch 80/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0118 - val_loss: 0.0150
# Epoch 81/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0118 - val_loss: 0.0140
# Epoch 82/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0136
# Epoch 83/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0115 - val_loss: 0.0135
# Epoch 84/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0114 - val_loss: 0.0139
# Epoch 85/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0116 - val_loss: 0.0138
# Epoch 86/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0119 - val_loss: 0.0140
# Epoch 87/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0162
# Epoch 88/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0138
# Epoch 89/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0118 - val_loss: 0.0138
# Epoch 90/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0115 - val_loss: 0.0142
# Epoch 91/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0115 - val_loss: 0.0134
# Epoch 92/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0115 - val_loss: 0.0135
# Epoch 93/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0116 - val_loss: 0.0148
# Epoch 94/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0115 - val_loss: 0.0153
# Epoch 95/100
# 262/262 [==============================] - 1s 2ms/step - loss: 0.0113 - val_loss: 0.0138
# Epoch 96/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0115 - val_loss: 0.0137
# Epoch 97/100
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0113 - val_loss: 0.0143
# Epoch 98/100
# 262/262 [==============================] - 1s 3ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 99/100
# 262/262 [==============================] - 2s 8ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 100/100
# 262/262 [==============================] - 2s 8ms/step - loss: 0.0113 - val_loss: 0.0136

# %%
print(f"Model training is completed!")
# Out:
# Model training is completed!

# %% [markdown]
# # 3) Artificial Neural Network Model Performance
#
# 1.   List item
# 2.   List item
#
#
#
# TODO: Bu modelin performansi nasil olculur bunu anlat!

# %%
# since model is trained, lets see how well the model performs against the test data (this was seperated before)
#print(f"Performans Artificial Neural Network is missing")

epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history["loss"]) # farkli renkte nasil cizilir?
plt.plot(epochs_hist.history["val_loss"])
plt.title("Model loss progress")
plt.xlabel("Epoch")
plt.ylabel("Training and Validation Loss")
plt.legend(["Training Loss", "Validation Loss"])

# %% [markdown]
# # 3.1) Model Prediction and Performance

# %%
X_test_scaled = scaler.fit_transform(X_test)

y_test = y_test.values.reshape(-1, 1)
y_test_scaled = scaler.fit_transform(y_test)

# %%
y_predict = model.predict(X_test_scaled)
# Out:
# 128/128 [==============================] - 0s 2ms/step

# %%
plt.plot(y_test_scaled, y_predict, "^", color = "r")
plt.xlabel("true values (scaled)")
plt.ylabel("predictions (scaled)")
# Out:
# Text(0, 0.5, 'predictions (scaled)')

# %%
# The predictions and the y values were scaled (normalized)
# Now, get the original values.

y_predict = scaler.inverse_transform(y_predict)

# %%
y_test # this is the original one.
# Out:
# array([[172700.],
#        [167200.],
#        [379300.],
#        ...,
#        [203700.],
#        [ 78600.],
#        [352800.]])

# %%
plt.plot(y_test, y_predict, "^", color = "r")
plt.xlabel("true values")
plt.ylabel("predictions")
# Out:
# Text(0, 0.5, 'predictions')

# %% [markdown]
# if the predictions were perfect, there would be a straight line where f(x) = x, with m = 1 (45 degree).
#
# TODO: Buraya bir perfect line cizelim.

# %% [markdown]
# https://ceb.udemy.com/course/machine-learning-regression-masterclass-in-python/learn/lecture/15154192#overview
#
# 13:41' de kaldim.

# %% [markdown]
# # Lets try to figure out model performance

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

k = X_test.shape[1] # number of features
n = len(X_test) # number of rows

#X_test.shape
#len(X_test)

RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)), ".3f"))
MSE = mean_squared_error(y_test, y_predict)
MAE = mean_absolute_error(y_test, y_predict)
r2 = r2_score(y_test, y_predict)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print("RMSE=", RMSE, "\nMSE=", MSE, "\nMAE=", MAE, "\nr2=", r2, "\nadj_r2=", adj_r2)
# Out:
# RMSE= 56618.566
# MSE= 3205662016.6394157
# MAE= 41250.72632935078
# r2= 0.7642336217464
# adj_r2= 0.7633649173313167
# (4087, 15)

# %% [markdown]
# RMSE= 56618.566 --> This is in the unit of the output (meaning dolars). So we are off ~ 56618 $ in the predictions.
#
# r2= 0.7642336217464 --> Each %75 change in the predicted value(y) is the result of the changes in the features.
